# %% [markdown]
# ## Section 3 Homework
#
# ## Algorithm:
# ### An algorithm is a step-by-step set of instructions to solve a problem or perform a task.
#
# ## Variable names may not start with certain characters - name two:
# ### Numbers and special symbols.
#
# ## Semantic error:
# ### Occurs when a program runs without crashing, but it doesn't produce the expected output because the code logic is flawed.
#
# ## 1 rule of coding/debugging:
# ### Break the problem into smaller, more manageable parts.
#
# ## List 5 Python reserved words:
# ### if
# ### else
# ### while
# ### for
# ### def

# %%
#Assign 5 different different data types to 5 different variables. At least one datatype must be a string
Integer = 5
Float = 3.1
String = "hello Roxanne"
Boolean = False
List = "bread, apples, milk"
print(Integer, Float, String, Boolean, List)

#print the length of your string
string_length = len(String)
print("length of the string:", string_length)

#print index value of the 4th character in your sting
String = "Roxanne"
fourth_character = String[4]
print("4th character:", fourth_character)

#Create a new variable called savvy, and assign it the string with this phrase "Learning Data Analytics and Python is Awesome!"
savvy =  "Learning Data Analytics and Python is Awesome!"

#Return a range of characters that slices the above string from the beginning of "ing" up to before "and"
savvy =  "Learning Data Analytics and Python is Awesome!"
print(savvy[5:-22])

#Replace "Awesome" with "great" in the string
savvy =  "Learning Data Analytics and Python is Awesome!"
print(savvy.replace("Awesome", "great"))

#Test and print the savvy string to see it contains "Python"

if "Python" in savvy:
	print("Yes, 'Python' is present.")

#Create and assign 3 more variables called name, age and length using the multi-variable naming method
name = "roxanne"
age = 33
length = 65

#Format a new string called 'miniBio' using variables in curly brackets to complete this phrase... "Hi my name is (name), I am (tall) and (so) old today."
name, age, length = "roxanne", 33, "5'5\""
miniBio = (f"Hi my name is {name} , I am {length}, and {age} years old today.")
#print 'miniBio'
print(miniBio)
#Cast and print the age variable to a float
age_float = float(age)
print("Age as float:", age_float)

#Create a list of at least 5 elements of mixed data types
list = ["Groceries", 5, 3.5, False, [1,2,3,4,5],2]
print(list)

#Replace a part of it with something else
list[1:4] = [4, True]
print(" replaced [1:4] ... ", list)

#Append or insert several more items to the list
list.append("watermelon")
print("New list ... ", list)

#Find and print the length of the list
listLength = len(list)
print("Size of the List = ", listLength)

#Slice a sub-section of the 1st list, and save it to a different 2nd list
start_index = 3 
end_index = 6     
newlist = list[start_index:end_index]

#Print the 2nd list
print(newlist)

#Extend your original list with the 2nd list sliced above
list.extend(newlist)
print("Extended list ... ", list)

##Create a new list called "simList" containing at least 5 elements of the same data type, either string, integer, float, or Boolean
simList = ["apples", "pears", "bread", "sugar", "lettuce"]

#Sort "simList", and print the list
simList.sort(reverse=True)
print("Sorted simList in reverse - ", simList)


#Copy the "simList" list to another 3rd list
list3 = simList.copy()
print('Copied List:', list3)

#Add the 2nd and 3rd lists together into a 4th list
list4= simList + list3
print("New added list ...", list4)

#Create a tuple of about 5 elements
tup1 = (1, 2, 3, 3, 5)

#Multiply your tuple by 3 and save it to a new 2nd tuple
timesTuple = tup1 * 3
print(timesTuple)

tup2 = 1, 2, 3, 3, 5, 1, 2, 3, 3, 5, 1, 2, 3, 3, 5

#Access and print the 12th element from the 2nd tuple
twelve_element = tup2[12]
print(twelve_element)

tup2 = 1, 2, 3, 3, 5, 1, 2, 3, 3, 5, 1, 2, 3, 3, 5
#Sort the 2nd tuple and print it
sorted_reverse_tup2 = tuple(sorted(tup2, reverse=True))
print(sorted_reverse_tup2)

#Copy 4 specific elements from your 2nd tuple to a new 3nd tuple
startindex = 1   # Index where copying starts (inclusive)
endindex = 5     # Index where copying ends (exclusive)
tup3 = tup2[startindex:endindex]

# Print the new third tuple
print(tup3)

#Unpack the 3rd tuple into 4 variables and print these variables

var1, var2, var3, var4 = tup3
print(var1)
print(var2)
print(var3) 
print(var4)

#Create a 4th tuple with single item 50 and print this tuple
tup4 = (50,)
print(tup4)

#Add the 2nd and 3rd tuple together into a 5th tuple and print the tuple
tup5 = tup2 + tup3
print(tup5)

#Create a set of about 3 elements
newset1 = {"blue", "green", "pink"}

#Add a list of fruits to the above set and print the result
newlset1 = {"blue", "green", "pink"}
newset2 = {"apple", "strawberries"}

newset3 = newset1.union(newset2)
print(newset3)

#Add a car element to your set
newset3.add("Honda")
print(newset3)

#Save the union of 1st set and 2nd set to a 3rd set
newset1 = {"blue", "green", "pink"}
newset2 = {"apple", "strawberries"}

newset3 = newset1.union(newlist2)
print(newset3)

#Pop an element from the 2nd set, and print the remainder of the set
newset2 = {"apple", "strawberries"}
newset2.pop()
print(newset2)

#Clear the 1st set and print the result
newset1 = {"blue", "green", "pink"}
newset1.clear()
print(newset1)

#Discard an element, and remove another element from the 3rd set
newset3.discard("apple")
print(newset3)

newset3.remove("blue")
print(newset3)

#Print the remainder of the 3rd set
print(newset3)

#Create a dictionary with at least 5 values of different data types
dict1 = {
	"color": "pink",
	"car": "subaru",
	"sport": "running",
	"state": "utah",
	"animal": "cat"
}
print(dict1)

#Print out 1 value
dict1.get("sport")

#Replace any one value in your dictionary with your name
dict1['state'] = "Roxanne"
print(dict1)

#Add your favorite color to the dictionary
dict1['favoritecolor'] = 'green'
print(dict1)

#Add a list, tuple or set to your dictionary
dict1['list1'] = [1, 2, 3, 4, 5]
print(dict1)

#Print a list of the dictionary keys
print(list(dict1.keys()))
#not sure what I am doing wrong here

#Print a list of the dictionary values
#Copy your 1st dictionary into a 2nd dictionary
#Pop an item from the 2nd dictionary, and print the dictionary
# Out:
# 5 3.1 hello Roxanne False bread, apples, milk
# length of the string: 13
# 4th character: n
# ing Data Analytics
# Learning Data Analytics and Python is great!
# Yes, 'Python' is present.
# Hi my name is roxanne , I am 5'5", and 33 years old today.
# Age as float: 33.0
# ['Groceries', 5, 3.5, False, [1, 2, 3, 4, 5], 2]
#  replaced [1:4] ...  ['Groceries', 4, True, [1, 2, 3, 4, 5], 2]
# New list ...  ['Groceries', 4, True, [1, 2, 3, 4, 5], 2, 'watermelon']
# Size of the List =  6
# [[1, 2, 3, 4, 5], 2, 'watermelon']
# Extended list ...  ['Groceries', 4, True, [1, 2, 3, 4, 5], 2, 'watermelon', [1, 2, 3, 4, 5], 2, 'watermelon']
# Sorted simList in reverse -  ['sugar', 'pears', 'lettuce', 'bread', 'apples']
# Copied List: ['sugar', 'pears', 'lettuce', 'bread', 'apples']
# New added list ... ['sugar', 'pears', 'lettuce', 'bread', 'apples', 'sugar', 'pears', 'lettuce', 'bread', 'apples']
# (1, 2, 3, 3, 5, 1, 2, 3, 3, 5, 1, 2, 3, 3, 5)
# 3
# (5, 5, 5, 3, 3, 3, 3, 3, 3, 2, 2, 2, 1, 1, 1)
# (2, 3, 3, 5)
# 2
# 3
# 3
# 5
# (50,)
# (1, 2, 3, 3, 5, 1, 2, 3, 3, 5, 1, 2, 3, 3, 5, 2, 3, 3, 5)
# {'pink', 'apple', 'green', 'strawberries', 'blue'}
# {'pink', 'Honda', 'apple', 'green', 'strawberries', 'blue'}
# {'pink', 'apple', 'green', 'strawberries', 'blue'}
# {'strawberries'}
# set()
# {'pink', 'green', 'strawberries', 'blue'}
# {'pink', 'green', 'strawberries'}
# {'pink', 'green', 'strawberries'}
# {'color': 'pink', 'car': 'subaru', 'sport': 'running', 'state': 'utah', 'animal': 'cat'}
# {'color': 'pink', 'car': 'subaru', 'sport': 'running', 'state': 'Roxanne', 'animal': 'cat'}
# {'color': 'pink', 'car': 'subaru', 'sport': 'running', 'state': 'Roxanne', 'animal': 'cat', 'favoritecolor': 'green'}
# {'color': 'pink', 'car': 'subaru', 'sport': 'running', 'state': 'Roxanne', 'animal': 'cat', 'favoritecolor': 'green', 'list1': [1, 2, 3, 4, 5]}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 201
#     198 print(dict1)
#     200 #Print a list of the dictionary keys
# --> 201 print(list(dict1.keys()))
#     203 #Print a list of the dictionary values
#     204 #Copy your 1st dictionary into a 2nd dictionary
#     205 #Pop an item from the 2nd dictionary, and print the dictionary
#
# TypeError: 'list' object is not callable
