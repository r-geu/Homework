# %%
#Flow Control Methods:

#Create an if statement: if 'age' is greater than or equal to 25, print "Renting a car is more affordable", however if 'age' is less than 25, print "Renting a car is very expensive."
age = 32

if age >= 25: print("Renting a car is more affordable")

if age < 25: print("Renting a car is very expensive.")

# Create and chain an if-else statement: if 'age' is greater than or equal to 25, print "Renting a car is more affordable." If 'age' is less than 25 but greater than or equal to 18, print "Renting a car is very expensive." Finally, if age is less than 18, print "You cannot legally rent a car."

if age >= 25:
    print("Renting a car is more affordable")
elif age >= 18:
    print("Renting a car is very expensive.")
else:
    print("You cannot legally rent a car.")

#Loop over the following string to (1) count all the characters in the string and (2) print out all the vowels -- "The quick brown fox jumps over the lazy dog"

sentence = "The quick brown fox jumps over the lazy dog"
vowels = "aeiouAEIOU"  

character_count = 0
for char in sentence:
    character_count += 1

print("Vowels in the sentence:")
for char in sentence:
    if char in vowels:
        print(char, end=" ")

print(character_count)

#Write a nested loop that prints out every piece of clothing from the couture list, in every fashionable color from the panettone set: couture = ["trousers", "blouse", "bandana", "cumber band", "blazer", "vest", "french beret", "scarf", "stole"] and panettone = {"cerise", "fuchsia", "aqua", "maple", "auburn", "burnt sienna", "gunmetal blue", "Dark Sapphire"}
couture = ["trousers", "blouse", "bandana", "cumber band", "blazer", "vest", "french beret", "scarf", "stole"] 
panettone = {"cerise", "fuchsia", "aqua", "maple", "auburn", "burnt sienna", "gunmetal blue", "Dark Sapphire"}

for clothing in couture:
    for color in panettone:
        print(f"{color} {clothing}")

#Use range as a loop to calculate the sum of all the numbers from 1 to 100
totalsum = 0

for number in range(1, 101):
    totalsum += number
print(totalsum)

#Print the second item in this fruits list. ["apple", "banana", "cherry"]
fruits = ["apple", "banana", "cherry"]
seconditem = fruits[1]
print(seconditem)

#Change the value from "apple" to "kiwi", in the fruits list. ["apple", "banana", "cherry"]
fruits = ["apple", "banana", "cherry"]
fruits[0] = "kiwi"
print(fruits)

#Use the append method to add "orange" to the fruits list. ["apple", "banana", "cherry"]
fruits.append("orange")
print(fruits)

#Use the insert method to add "lemon" as the second item in the fruits list. ["apple", "banana", "cherry"]
fruits.insert(1, "lemon")
print(fruits)

#Use the remove method to remove "banana" from the fruits list. ["apple", "banana", "cherry"]
fruits.remove("banana")
print(fruits)

#Use negative indexing to print the 3rd and 2nd to last items in the list. ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]
newfruitlist = ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]

third = newfruitlist[2] 
secondtolast = newfruitlist[-2] 

print(third)
print(secondtolast)

#Use a range of indexes to print the third, fourth, and fifth item in the list. ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]
selecteditems = newfruitlist[2:5]
print(selecteditems)

#Use the correct syntax to print the number of items in the list. ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]
numitems = len(fruits)
print(numitems)

#Use the correct syntax to sort this list in reverse order ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]
fruits.sort(reverse=True)
print(fruits)

# Use the DateTime module to get Current Date and Time, and save it to a variable. Then extract just the Full month name form that variable.
import datetime
currentdatetime = datetime.datetime.now()
fullmonth_name = currentdatetime.strftime('%B')

# Write a simple function that takes 2 parameters -- a first name and a day name. (1)Set a default value for the day name of Sunday.(2)Have the function print out a greeting -- using the parameters -- that says something like "Hi first-name! Happy day-name!". Remember to use the variables in the greeting to replace first-name and day-name.(3) Invoke this function with 2 variables. Invoke this function with 1 variable only.

dayname = "Sunday"
firstname = "roxanne"
def greeting(firstname, dayname='Sunday'):
    print(f"Hi {firstname}! Happy {dayname}!")


# Write a block of code to handle one of the most common Python exception errors. Select one of the common errors from the curriculum section on Python Exception handling. Have your code example uses the try,except, else, and finally components.
try:
    num = int("123")
except ValueError:
    print("Error: Invalid conversion to integer.")
else:
    print("Conversion successful.")
finally:
    print("Exception handling completed.")
# Out:
# Renting a car is more affordable
# Renting a car is more affordable
# Vowels in the sentence:
# e u i o o u o e e a o 43
# gunmetal blue trousers
# aqua trousers
# fuchsia trousers
# Dark Sapphire trousers
# burnt sienna trousers
# cerise trousers
# maple trousers
# auburn trousers
# gunmetal blue blouse
# aqua blouse
# fuchsia blouse
# Dark Sapphire blouse
# burnt sienna blouse
# cerise blouse
# maple blouse
# auburn blouse
# gunmetal blue bandana
# aqua bandana
# fuchsia bandana
# Dark Sapphire bandana
# burnt sienna bandana
# cerise bandana
# maple bandana
# auburn bandana
# gunmetal blue cumber band
# aqua cumber band
# fuchsia cumber band
# Dark Sapphire cumber band
# burnt sienna cumber band
# cerise cumber band
# maple cumber band
# auburn cumber band
# gunmetal blue blazer
# aqua blazer
# fuchsia blazer
# Dark Sapphire blazer
# burnt sienna blazer
# cerise blazer
# maple blazer
# auburn blazer
# gunmetal blue vest
# aqua vest
# fuchsia vest
# Dark Sapphire vest
# burnt sienna vest
# cerise vest
# maple vest
# auburn vest
# gunmetal blue french beret
# aqua french beret
# fuchsia french beret
# Dark Sapphire french beret
# burnt sienna french beret
# cerise french beret
# maple french beret
# auburn french beret
# gunmetal blue scarf
# aqua scarf
# fuchsia scarf
# Dark Sapphire scarf
# burnt sienna scarf
# cerise scarf
# maple scarf
# auburn scarf
# gunmetal blue stole
# aqua stole
# fuchsia stole
# Dark Sapphire stole
# burnt sienna stole
# cerise stole
# maple stole
# auburn stole
# 5050
# banana
# ['kiwi', 'banana', 'cherry']
# ['kiwi', 'banana', 'cherry', 'orange']
# ['kiwi', 'lemon', 'banana', 'cherry', 'orange']
# ['kiwi', 'lemon', 'cherry', 'orange']
# cherry
# melon
# ['cherry', 'orange', 'kiwi']
# 4
# ['orange', 'lemon', 'kiwi', 'cherry']
# Conversion successful.
# Exception handling completed.

# %% [markdown]
# ### ** Python Homework (Flow Control, Modules, Functions, Exceptions, NumPy)**
#
# #### 1. Import using the import statement
# #### 2. import math print((math.sqrt(9))
# #### 3. Helps writing more robust and fault-tolerant code
# #### 4. Try, except, else, finally
# #### 5. Python lists
# #### 6. Speed
# #### 7. data type  of element should be consistent
# #### 8. (1) Performing mathematical and statistical operations on large datasets (2) Manipulating arrays and matrices for scientific computing and machine learning.
# #### 9. Pandas
# #### 10. dimensions of the array
# #### 11. Multi-dimensional arrays used to represent data.
# #### 12. NumPy arrays offer better performance and memory efficiency compared to Python lists
# #### 13.
